# %%
from qaoamis import QAOAMIS

mis = QAOAMIS()
penalty = 1

mis.addNodes(7)

mis.visualize()
# Out:
# 7

# %%
mis.buildQUBO(penalty=penalty)
brute_force_sol = mis.mis_brute_force(show_graph=True, print_expected_energy_bar=True)

# %%
mis.buildCostHamiltonian(penalty=penalty)
circuit = mis.buildQAOAAnsatz(layers=3)

print(circuit)
# Out:
#      ┌──────────────────────────────────────┐
# q_0: ┤0                                     ├
#      │                                      │
# q_1: ┤1                                     ├
#      │                                      │
# q_2: ┤2                                     ├
#      │                                      │
# q_3: ┤3 QAOA(γ[0],β[0],γ[1],β[1],γ[2],β[2]) ├
#      │                                      │
# q_4: ┤4                                     ├
#      │                                      │
# q_5: ┤5                                     ├
#      │                                      │
# q_6: ┤6                                     ├
#      └──────────────────────────────────────┘

# %%
beta, gamma = mis.find_optimal_parameters()
# Out:
# /home/tuthuanvanvn/miniconda3/envs/molssi_best_practices/lib/python3.11/site-packages/scipy/sparse/linalg/_dsolve/linsolve.py:597: SparseEfficiencyWarning: splu converted its input to CSC format
#   return splu(A).solve
# /home/tuthuanvanvn/miniconda3/envs/molssi_best_practices/lib/python3.11/site-packages/scipy/sparse/linalg/_matfuncs.py:707: SparseEfficiencyWarning: spsolve is more efficient when sparse b is in the CSC matrix format
#   return spsolve(Q, P)
# /home/tuthuanvanvn/miniconda3/envs/molssi_best_practices/lib/python3.11/site-packages/scipy/sparse/_index.py:168: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil and dok are more efficient.
#   self._set_intXint(row, col, x.flat[0])

# %%
print(beta, gamma)
mis.qaoa_evaluate(beta, gamma, shots=2 ** 16, print_count=True)
# Out:
# [2.36817744 3.62810316 2.73027814] [1.77928027 1.41146266 2.06486571]
# {np.str_('0000000'): np.int64(88),
#  np.str_('0000001'): np.int64(137),
#  np.str_('0000010'): np.int64(146),
#  np.str_('0000011'): np.int64(231),
#  np.str_('0000100'): np.int64(168),
#  np.str_('0000101'): np.int64(263),
#  np.str_('0000110'): np.int64(238),
#  np.str_('0000111'): np.int64(330),
#  np.str_('0001000'): np.int64(140),
#  np.str_('0001001'): np.int64(245),
#  np.str_('0001010'): np.int64(228),
#  np.str_('0001011'): np.int64(360),
#  np.str_('0001100'): np.int64(256),
#  np.str_('0001101'): np.int64(328),
#  np.str_('0001110'): np.int64(361),
#  np.str_('0001111'): np.int64(584),
#  np.str_('0010000'): np.int64(142),
#  np.str_('0010001'): np.int64(248),
#  np.str_('0010010'): np.int64(217),
#  np.str_('0010011'): np.int64(333),
#  np.str_('0010100'): np.int64(242),
#  np.str_('0010101'): np.int64(368),
#  np.str_('0010110'): np.int64(340),
#  np.str_('0010111'): np.int64(560),
#  np.str_('0011000'): np.int64(247),
#  np.str_('0011001'): np.int64(346),
#  np.str_('0011010'): np.int64(351),
#  np.str_('0011011'): np.int64(506),
#  np.str_('0011100'): np.int64(356),
#  np.str_('0011101'): np.int64(542),
#  np.str_('0011110'): np.int64(493),
#  np.str_('0011111'): np.int64(854),
#  np.str_('0100000'): np.int64(137),
#  np.str_('0100001'): np.int64(248),
#  np.str_('0100010'): np.int64(241),
#  np.str_('0100011'): np.int64(319),
#  np.str_('0100100'): np.int64(228),
#  np.str_('0100101'): np.int64(348),
#  np.str_('0100110'): np.int64(362),
#  np.str_('0100111'): np.int64(534),
#  np.str_('0101000'): np.int64(239),
#  np.str_('0101001'): np.int64(324),
#  np.str_('0101010'): np.int64(364),
#  np.str_('0101011'): np.int64(504),
#  np.str_('0101100'): np.int64(350),
#  np.str_('0101101'): np.int64(557),
#  np.str_('0101110'): np.int64(554),
#  np.str_('0101111'): np.int64(850),
#  np.str_('0110000'): np.int64(224),
#  np.str_('0110001'): np.int64(345),
#  np.str_('0110010'): np.int64(368),
#  np.str_('0110011'): np.int64(532),
#  np.str_('0110100'): np.int64(353),
#  np.str_('0110101'): np.int64(545),
#  np.str_('0110110'): np.int64(537),
#  np.str_('0110111'): np.int64(812),
#  np.str_('0111000'): np.int64(373),
#  np.str_('0111001'): np.int64(528),
#  np.str_('0111010'): np.int64(576),
#  np.str_('0111011'): np.int64(859),
#  np.str_('0111100'): np.int64(539),
#  np.str_('0111101'): np.int64(879),
#  np.str_('0111110'): np.int64(854),
#  np.str_('0111111'): np.int64(1276),
#  np.str_('1000000'): np.int64(137),
#  np.str_('1000001'): np.int64(243),
#  np.str_('1000010'): np.int64(252),
#  np.str_('1000011'): np.int64(367),
#  np.str_('1000100'): np.int64(226),
#  np.str_('1000101'): np.int64(350),
#  np.str_('1000110'): np.int64(379),
#  np.str_('1000111'): np.int64(558),
#  np.str_('1001000'): np.int64(238),
#  np.str_('1001001'): np.int64(361),
#  np.str_('1001010'): np.int64(371),
#  np.str_('1001011'): np.int64(540),
#  np.str_('1001100'): np.int64(341),
#  np.str_('1001101'): np.int64(578),
#  np.str_('1001110'): np.int64(546),
#  np.str_('1001111'): np.int64(850),
#  np.str_('1010000'): np.int64(243),
#  np.str_('1010001'): np.int64(372),
#  np.str_('1010010'): np.int64(334),
#  np.str_('1010011'): np.int64(522),
#  np.str_('1010100'): np.int64(384),
#  np.str_('1010101'): np.int64(496),
#  np.str_('1010110'): np.int64(593),
#  np.str_('1010111'): np.int64(841),
#  np.str_('1011000'): np.int64(324),
#  np.str_('1011001'): np.int64(491),
#  np.str_('1011010'): np.int64(524),
#  np.str_('1011011'): np.int64(848),
#  np.str_('1011100'): np.int64(566),
#  np.str_('1011101'): np.int64(813),
#  np.str_('1011110'): np.int64(814),
#  np.str_('1011111'): np.int64(1281),
#  np.str_('1100000'): np.int64(241),
#  np.str_('1100001'): np.int64(330),
#  np.str_('1100010'): np.int64(336),
#  np.str_('1100011'): np.int64(524),
#  np.str_('1100100'): np.int64(400),
#  np.str_('1100101'): np.int64(494),
#  np.str_('1100110'): np.int64(557),
#  np.str_('1100111'): np.int64(823),
#  np.str_('1101000'): np.int64(353),
#  np.str_('1101001'): np.int64(548),
#  np.str_('1101010'): np.int64(524),
#  np.str_('1101011'): np.int64(811),
#  np.str_('1101100'): np.int64(530),
#  np.str_('1101101'): np.int64(831),
#  np.str_('1101110'): np.int64(782),
#  np.str_('1101111'): np.int64(1289),
#  np.str_('1110000'): np.int64(329),
#  np.str_('1110001'): np.int64(546),
#  np.str_('1110010'): np.int64(566),
#  np.str_('1110011'): np.int64(787),
#  np.str_('1110100'): np.int64(550),
#  np.str_('1110101'): np.int64(854),
#  np.str_('1110110'): np.int64(848),
#  np.str_('1110111'): np.int64(1217),
#  np.str_('1111000'): np.int64(548),
#  np.str_('1111001'): np.int64(825),
#  np.str_('1111010'): np.int64(831),
#  np.str_('1111011'): np.int64(1297),
#  np.str_('1111100'): np.int64(850),
#  np.str_('1111101'): np.int64(1202),
#  np.str_('1111110'): np.int64(1212),
#  np.str_('1111111'): np.int64(1911)}
